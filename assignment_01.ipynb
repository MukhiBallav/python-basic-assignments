# %%
print("this is a multi heredoc string")
# Out:
# this is a multi heredoc string

# %%
print('''Sample string :
a string that you "don't" have to escape

This
is a ....... multi-line
heredoc string --------> example''')
# Out:
# Sample string :
# a string that you "don't" have to escape
#
# This
# is a ....... multi-line
# heredoc string --------> example

# %%
x=4
y=3
z=(x+y)*(x+y)
print(z)
# Out:
# 49

# %%
princ=10000
roi=3.5
yrs=7
amt=princ*((1+roi)**yrs)
print(amt)
# Out:
# 373669453.125

# %%
base=float(input('enter base:'))
height=float(input('enter height:'))
area=0.5*base*height
print('area of triangle:',area)
# Out:
# enter base: 2
# enter height: 3
# area of triangle: 3.0

# %%
name=input("enter your name:")
age=input("enter your age:")
address=input("enter your address:")
print=(name)
print=(age)
print=(address)
# Out:
# enter your name: m
# enter your age: 3
# enter your address: c

# %%
def check_values(a,b):
    if a==b or (a+b)==5 or (a-b)==5:
        return true
    else:
        return false

# %%
a=int(input("enter number"))
b=int(input("enter other number"))
if a==b or (a+b)==5 or abs(a-b)==5:
    print(True)
else: 
    print(False)
# Out:
# enter number 3
# enter other number 4
# False
